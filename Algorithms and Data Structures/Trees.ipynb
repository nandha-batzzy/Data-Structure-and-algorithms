# %%
class tree():
    def __init__(self,data):
        self.data = data
        self.children = []
        self.parent = None
    def add_child(self,child):
        child.parent = self
        self.children.append(child)
        
    def get_count(self):
        lvl = 0
        p = self.parent
        while p:
            lvl = lvl+1
            p = p.parent
        return lvl
        
    def print_tree(self):
        space = " " * self.get_count()* 3
        print(space,"!__",self.data)
        for child in self.children:
            child.print_tree()
            
        
def bulding_tree():
    root = tree('Electronics')

    laptop = tree('Laptop')
    laptop.add_child(tree('samsung'))
    laptop.add_child(tree('sony'))

    tv = tree('TV')
    tv.add_child(tree('MI'))
    tv.add_child(tree('Realme'))

    root.add_child(laptop)
    root.add_child(tv)

    return root
if __name__ == '__main__':
    root = bulding_tree()
    root.print_tree()
    pass
# Out:
#  !__ Electronics
#     !__ Laptop
#        !__ samsung
#        !__ sony
#     !__ TV
#        !__ MI
#        !__ Realme

# %%
class tree():
    def __init__(self,data):
        self.data = data
        self.children = []
        self.parent = None
    def add_child(self,child):
        child.parent = self
        self.children.append(child)
    
    def get_lvl(self):
        lvl = 0
        p  = self.parent
        while p:
            lvl = lvl+1
            p = p.parent
        return lvl
        
    def print_tre(self):
        indent = " "*self.get_lvl()*3
        print(indent,'!__',self.data)
        for child in self.children:
            child.print_tre()
            
            
        
def building_mtree(categ):
    if categ == 'name':
        root = tree('Nipul')

        vishwa = tree('Vishwa')
        vishwa.add_child(tree('Dhaval'))
        vishwa.add_child(tree('Abhijit'))

        chinmay = tree('Chinmay')
        chinmay.add_child(vishwa)
        chinmay.add_child(tree('Aamir'))

        gels = tree('Gels')
        gels.add_child(tree('Peter'))
        gels.add_child(tree('Waqas'))


        root.add_child(chinmay)
        root.add_child(gels)
        
    if categ == 'designation':
        root = tree('CEO')

        vishwa = tree('Infrastructure Head')
        vishwa.add_child(tree('Cloud Manager'))
        vishwa.add_child(tree('App Manager'))

        chinmay = tree('CTO')
        chinmay.add_child(vishwa)
        chinmay.add_child(tree('Application Head'))

        gels = tree('HR Head')
        gels.add_child(tree('Recruitment Manager'))
        gels.add_child(tree('Policy Manager'))


        root.add_child(chinmay)
        root.add_child(gels)
        
    if categ == 'both':
        root = tree('Nipul (CEO)')

        vishwa = tree('Vishwa (Infrastructure Head)')
        vishwa.add_child(tree('Dhaval (Cloud Manager)'))
        vishwa.add_child(tree('Abhijit (App Manager)'))

        chinmay = tree('Chinmay (CTO)')
        chinmay.add_child(vishwa)
        chinmay.add_child(tree('Aamir (Application Head)'))

        gels = tree('Gels (HR Head)')
        gels.add_child(tree('Peter (Recruitment Manager)'))
        gels.add_child(tree('Waqas (Policy Manager)'))


        root.add_child(chinmay)
        root.add_child(gels)
    return root

if __name__ == '__main__':
    root = building_mtree('both')
    root.print_tre()
    pass
# Out:
#  !__ Nipul (CEO)
#     !__ Chinmay (CTO)
#        !__ Vishwa (Infrastructure Head)
#           !__ Dhaval (Cloud Manager)
#           !__ Abhijit (App Manager)
#        !__ Aamir (Application Head)
#     !__ Gels (HR Head)
#        !__ Peter (Recruitment Manager)
#        !__ Waqas (Policy Manager)

# %%
class tree():
    def __init__(self,data):
        self.data = data
        self.children = []
        self.parent = None
    def add_child(self,child):
        child.parent = self
        self.children.append(child)
    
    def get_lvl(self):
        lvl = 0
        p  = self.parent
        while p:
            lvl = lvl+1
            p = p.parent
        return lvl
        
    def print_tre(self,levl):
        if levl >= 0:
            indent = " "*self.get_lvl()*3
            print(indent,'!__',self.data)
        for child in self.children:
            child.print_tre(levl-1)
            
            
def building_mtree():
    root = tree('Global')
    
    
    
    Gujarat = tree('Gujarat')
    Gujarat.add_child(tree('Ahmedabad'))
    Gujarat.add_child(tree('Baroda'))
    
    Karnataka = tree('Karnataka')
    Karnataka.add_child(tree('Bangalore'))
    Karnataka.add_child(tree('Mysore'))
    
    New_Jersey = tree('New jersey')
    New_Jersey.add_child(tree('Princeton'))
    New_Jersey.add_child(tree('Trenton'))
    
    California = tree('California')
    California.add_child(tree('San Francisco'))
    California.add_child(tree('Mountain View'))
    California.add_child(tree('Palo Alto'))
    
    USA = tree('USA')
    USA.add_child(New_Jersey)
    USA.add_child(California)
    
    India = tree('India')
    India.add_child(Gujarat)
    India.add_child(Karnataka)
    
    root.add_child(USA)
    root.add_child(India)
    return root

if __name__ == '__main__':
    root = building_mtree()
    root.print_tre(2)
    pass
# Out:
#  !__ Global
#     !__ USA
#        !__ New jersey
#        !__ California
#     !__ India
#        !__ Gujarat
#        !__ Karnataka
